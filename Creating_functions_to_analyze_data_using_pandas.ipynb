# %% [markdown]
# <a href="https://colab.research.google.com/github/sarada-atluri/ML-Using-pandas/blob/main/Creating_functions_to_analyze_data_using_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
# mount the drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#read file from the drive
import pandas as pd

# %%
datasetpath = '/content/drive/MyDrive/Document from Sarada'

# %%
df = pd.read_csv(datasetpath)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df.shape
# Out:
# (964, 44)

# %%
age = []
height = []
weight = []

# %%
df.shape
# Out:
# (964, 44)

# %%
import random

# %%
# Loop comprehension
[age.append(random.randint(18,40)) for _ in range(964)]
print(f"Age is now having {len(age)}")
# Out:
# Age is now having 964

# %%
age
# Out:
# [39,
#  30,
#  35,
#  40,
#  24,
#  24,
#  25,
#  36,
#  20,
#  32,
#  18,
#  38,
#  22,
#  39,
#  40,
#  28,
#  27,
#  23,
#  37,
#  33,
#  24,
#  37,
#  28,
#  28,
#  22,
#  19,
#  23,
#  34,
#  36,
#  38,
#  28,
#  35,
#  18,
#  20,
#  31,
#  26,
#  31,
#  40,
#  30,
#  38,
#  37,
#  29,
#  19,
#  22,
#  28,
#  32,
#  30,
#  38,
#  18,
#  34,
#  24,
#  38,
#  39,
#  22,
#  21,
#  39,
#  34,
#  22,
#  35,
#  20,
#  25,
#  29,
#  33,
#  27,
#  40,
#  37,
#  30,
#  34,
#  26,
#  32,
#  24,
#  26,
#  22,
#  21,
#  29,
#  40,
#  32,
#  34,
#  36,
#  34,
#  24,
#  34,
#  21,
#  39,
#  37,
#  19,
#  20,
#  30,
#  31,
#  18,
#  39,
#  30,
#  27,
#  25,
#  30,
#  30,
#  39,
#  40,
#  31,
#  19,
#  31,
#  25,
#  33,
#  18,
#  37,
#  23,
#  40,
#  27,
#  24,
#  40,
#  24,
#  31,
#  37,
#  26,
#  36,
#  32,
#  21,
#  31,
#  23,
#  27,
#  38,
#  29,
#  33,
#  34,
#  26,
#  31,
#  20,
#  24,
#  31,
#  18,
#  20,
#  20,
#  37,
#  37,
#  19,
#  19,
#  31,
#  29,
#  18,
#  34,
#  40,
#  38,
# ...

# %%
#Adding a new column DataFrame
#syntax:df['New column Name']list/series of elements

# %%
df['Years of Experience'] = age

# %%
age
# Out:
# [39,
#  30,
#  35,
#  40,
#  24,
#  24,
#  25,
#  36,
#  20,
#  32,
#  18,
#  38,
#  22,
#  39,
#  40,
#  28,
#  27,
#  23,
#  37,
#  33,
#  24,
#  37,
#  28,
#  28,
#  22,
#  19,
#  23,
#  34,
#  36,
#  38,
#  28,
#  35,
#  18,
#  20,
#  31,
#  26,
#  31,
#  40,
#  30,
#  38,
#  37,
#  29,
#  19,
#  22,
#  28,
#  32,
#  30,
#  38,
#  18,
#  34,
#  24,
#  38,
#  39,
#  22,
#  21,
#  39,
#  34,
#  22,
#  35,
#  20,
#  25,
#  29,
#  33,
#  27,
#  40,
#  37,
#  30,
#  34,
#  26,
#  32,
#  24,
#  26,
#  22,
#  21,
#  29,
#  40,
#  32,
#  34,
#  36,
#  34,
#  24,
#  34,
#  21,
#  39,
#  37,
#  19,
#  20,
#  30,
#  31,
#  18,
#  39,
#  30,
#  27,
#  25,
#  30,
#  30,
#  39,
#  40,
#  31,
#  19,
#  31,
#  25,
#  33,
#  18,
#  37,
#  23,
#  40,
#  27,
#  24,
#  40,
#  24,
#  31,
#  37,
#  26,
#  36,
#  32,
#  21,
#  31,
#  23,
#  27,
#  38,
#  29,
#  33,
#  34,
#  26,
#  31,
#  20,
#  24,
#  31,
#  18,
#  20,
#  20,
#  37,
#  37,
#  19,
#  19,
#  31,
#  29,
#  18,
#  34,
#  40,
#  38,
# ...

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
df['Asp']=df['Years of Experience']*df['home_score']

# %%
df.shape
# Out:
# (964, 46)

# %%
df
# Out:
#          home_team away_team  home_score  home_xg  home_penalty  away_score  \
# 0        Argentina    France           3      3.3           4.0           3
# 1          Croatia   Morocco           2      0.7           NaN           1
# 2           France   Morocco           2      2.0           NaN           0
# 3        Argentina   Croatia           3      2.3           NaN           0
# 4          Morocco  Portugal           1      1.4           NaN           0
# ..             ...       ...         ...      ...           ...         ...
# 959      Argentina    France           1      NaN           NaN           0
# 960     Yugoslavia    Brazil           2      NaN           NaN           1
# 961        Romania      Peru           3      NaN           NaN           1
# 962  United States   Belgium           3      NaN           NaN           0
# 963         France    Mexico           4      NaN           NaN           1
#
# ...

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
df['Asp'].plot(kind='bar',color='red')
# Out:
# <Axes: >

# %%
df.plot(x='Years of Experience',y='Asp',kind='scatter',color='green')
# Out:
# <Axes: xlabel='Years of Experience', ylabel='Asp'>

# %%
df.plot(x='Asp',y=['away_score','home_score'],kind='bar',color=['blue','red'])
# Out:
# <Axes: xlabel='Asp'>

# %%
# Error:same length_NaN_Not a Number_dtype_Numpy_Q

# %%
def getGraph(DataFrame,column1,column2):
  from matplotlib import pyplot as plt
  if len(DataFrame[column1])==len(DataFrame[column2]):
      df.plot(x=column1,y=column2,kind='bar',color=['pink','black'])
      print('the graph/plot is successfully created ')

  else:
     print('please check the column size once')

# %%
getGraph (df,'home_score','away_score')
# Out:
# the graph/plot is successfully created
